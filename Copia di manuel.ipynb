# %%
# !pip install vtk
# !pip install meshio
# Out:
# Collecting vtk
#   Downloading vtk-9.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.3 kB)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from vtk) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->vtk) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->vtk) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->vtk) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->vtk) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.21 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->vtk) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->vtk) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->vtk) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->vtk) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->vtk) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->vtk) (1.16.0)
# Downloading vtk-9.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (105.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 MB 8.1 MB/s eta 0:00:00
# Installing collected packages: vtk
# Successfully installed vtk-9.4.0
# Collecting meshio
#   Downloading meshio-5.3.5-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from meshio) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from meshio) (13.9.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->meshio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->meshio) (2.18.0)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from rich->meshio) (4.12.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->meshio) (0.1.2)
# Downloading meshio-5.3.5-py3-none-any.whl (166 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.2/166.2 kB 12.0 MB/s eta 0:00:00
# Installing collected packages: meshio
# Successfully installed meshio-5.3.5

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import os
import vtkmodules.all as vtk
from vtkmodules.util.numpy_support import vtk_to_numpy, numpy_to_vtk
import meshio
from scipy.spatial.distance import cdist
from torchvision import datasets, transforms

# %%
from google.colab import drive
drive.mount('/content/drive')

#device=torch.device('cpu')
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# Mounted at /content/drive

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
DATASET_PATH = "/content/drive/MyDrive/Colab Notebooks/ML project 2/dataset"

# %%
fields = {'velocity', 'pressure'}

basis_space, sv_space, Nh_space, nmodes_space = dict(), dict(), dict(), dict()
basis_time, sv_time, Nh_time, nmodes_time = dict(), dict(), dict(), dict()
nmodes = dict()
for field in fields:
    basis_space[field] = np.load(os.path.join(DATASET_PATH, 'basis', field, 'space_basis.npy'))  # spatial basis
    sv_space[field] = np.load(os.path.join(DATASET_PATH, 'basis', field, 'space_sv.npy'))  # singular values in space
    Nh_space[field], nmodes_space[field] = basis_space[field].shape  # number of FOM and ROM unknowns in space
    basis_time[field] = np.load(os.path.join(DATASET_PATH, 'basis', field, 'time_basis.npy'))  # temporal basis
    sv_time[field] = np.load(os.path.join(DATASET_PATH, 'basis', field, 'time_sv.npy'))  # singular values in time
    Nh_time[field], nmodes_time[field] = basis_time[field].shape  # number of FOM and ROM unknowns in time
    nmodes[field] = nmodes_space[field] * nmodes_time[field]  # total dimension of the reduced basis

# UPDATE VELOCITY BASES TO ACCOUNT FOR SUPREMIZERS AND STABILIZERS
N_supr_space = basis_space['pressure'].shape[1] + 66  # number of extra bases in space for the velocity
N_supr_time = 5  # number of extra bases in time for the velocity

# STORE ORIGINAL NUMBER OF VELOCITY MODES IN THE DICTIONARY
nmodes_space['velocity_full'] = nmodes_space['velocity']
nmodes_time['velocity_full'] = nmodes_time['velocity']
nmodes['velocity_full'] = nmodes['velocity']

# UPDATE THE NUMBER OF VELOCITY MODES TO ACCOUNT FOR SUPREMIZERS AND STABILIZERS
nmodes_space['velocity'] -= N_supr_space
nmodes_time['velocity'] -= N_supr_time
nmodes['velocity'] = nmodes_space['velocity'] * nmodes_time['velocity']

# UPDATE VELOCITY BASES TO ACCOUNT FOR SUPREMIZERS AND STABILIZERS
basis_space['velocity'] = basis_space['velocity'][:, :nmodes_space['velocity']]
basis_time['velocity'] = basis_time['velocity'][:, :nmodes_time['velocity']]

# LOAD NORMED BASIS MATRICES IN SPACE (needed for projections)
basis_space_normed = dict()
#norm = dict()
for field in fields:
    #norm[field] = load_npz(os.path.join('dataset', 'norms', f'norm_{field}.npz'))
    #basis_space_normed[field] = norm[field].dot(basis_space[field])
    #np.save(os.path.join('dataset', 'basis', field, 'basis_space_normed.npy'), basis_space_normed[field])
    basis_space_normed[field] = np.load(os.path.join(DATASET_PATH, 'basis', field, 'basis_space_normed.npy'))

# %%
params = np.load(os.path.join(DATASET_PATH, 'RB_data', 'parameters.npy'))
params = np.delete(params, 2, axis=1)

# %%
n_snaps = None  # change to a number if you want to load only a subset of snapshots
_sol = np.load(os.path.join(DATASET_PATH, 'RB_data', 'solutions.npy'))[:n_snaps]

solutions = dict()

# velocity reduced solutions (with and without supremizers and stabilizers)
solutions['velocity_full'] = np.reshape(_sol[:, :nmodes['velocity_full']],
                                        (-1, nmodes_space['velocity_full'], nmodes_time['velocity_full']))
solutions['velocity'] = solutions['velocity_full'][:, :nmodes_space['velocity'], :nmodes_time['velocity']]

# pressure reduced solutions
solutions['pressure'] = np.reshape(_sol[:, :nmodes['pressure']],
                                   (-1, nmodes_space['pressure'], nmodes_time['pressure']))

# %%
basis_space['velocity'].shape #Vs = Ns *ns
# Out:
# (76974, 39)

# %%
basis_time['velocity'].shape
# Out:
# (1000, 16)

# %%
basis_space['pressure'].shape

# %%
basis_time['pressure'].shape

# %%
solutions['pressure'].shape

# %%
solutions['velocity'].shape

# %%
solutions['pressure']= torch.tensor(solutions['pressure'], dtype=torch.float32)
solutions['velocity']= torch.tensor(solutions['velocity'], dtype=torch.float32)
params = torch.tensor(params, dtype=torch.float32)

# %%
class Fluid_Dataset(Dataset):
    def __init__(self, inputs, targets):
        self.inputs = inputs
        self.targets =  targets

    def __len__(self):
        return self.inputs.shape[0]

    def __getitem__(self, idx):

        input = self.inputs[idx]
        output = self.targets[idx]
        return input, output

# %%
N_data=params.shape[0]
indices = torch.randperm(N_data)
ratio_data=0.8
train_size = int(ratio_data * N_data)
train_indices = indices[:train_size]
test_indices=indices[train_size:]



train_params=params[train_indices]
test_params=params[test_indices]

mean_params=torch.mean(train_params,dim=0)
std_params=torch.std(train_params,dim=0)
train_params=(train_params-mean_params)/std_params
test_params=(test_params-mean_params)/std_params


train_vel=solutions['velocity'][train_indices]

test_vel=solutions['velocity'][test_indices]

train_press=solutions['pressure'][train_indices]
test_press=solutions['pressure'][test_indices]

# %%
#STANDARDITZAION ALTERNATIVE ZERO
vel_space_mean = torch.mean(train_vel, dim= 0)
vel_space_std = torch.std(train_vel, dim=0)
train_vel = (train_vel - vel_space_mean) / vel_space_std

test_vel = (test_vel - vel_space_mean) / vel_space_std

# %%
print(train_vel.mean())
print(test_vel.mean())
# Out:
# tensor(1.1839e-08)
# tensor(0.0025)

# %%
#STANDARDITZAION ALTERNATIVE ONE
vel_space_mean = torch.mean(train_vel, dim=1, keepdim=True)
vel_space_std = torch.std(train_vel, dim=1, keepdim=True)
train_vel = (train_vel - vel_space_mean) / vel_space_std
test_vel =(test_vel - vel_space_mean) / vel_space_std


vel_time_mean = torch.mean(train_vel, dim=2, keepdim=True)
vel_time_std = torch.std(train_vel, dim=2, keepdim=True)
train_vel = (train_vel - vel_time_mean) / vel_time_std
test_vel =(test_vel - vel_time_mean) / vel_time_std
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-78-24dae9669538> in <cell line: 5>()
#       3 vel_space_std = torch.std(train_vel, dim=1, keepdim=True)  # Devi usare torch.std qui!
#       4 train_vel = (train_vel - vel_space_mean) / vel_space_std
# ----> 5 test_vel =(test_vel - vel_space_mean) / vel_space_std
#       6
#       7 # Normalizzazione lungo la dimensione temporale (dim=2)
#
# RuntimeError: The size of tensor a (390) must match the size of tensor b (1560) at non-singleton dimension 0

# %%
train_params.shape

# %%
test_params.shape

# %%
train_vel.shape

# %%
test_vel.shape

# %%
#IGNORE THIS FOR THE MOMENT
class MLP_press_ConvAutoencoder(torch.nn.Module):
    def __init__(self, parameters=3, dim_1=39, dim_2=16, dim_1_reduced=18, dim_2_reduced=8, L=4, K=256):
        super(MLP_press_ConvAutoencoder, self).__init__()

        self.mlp = torch.nn.Sequential(
            *[layer for i in range(L) for layer in [
                torch.nn.Linear(parameters if i == 0 else K, K),
                torch.nn.LayerNorm(K),
                torch.nn.GELU(),
            ]],
            torch.nn.Linear(K, dim_1_reduced * dim_2_reduced),
            torch.nn.Unflatten(1, (dim_1_reduced, dim_2_reduced))  # Reshaping to (-1, dim_1_reduced, dim_2_reduced)
        )

        # Encoder
        self.encoder = torch.nn.Sequential(
            torch.nn.Conv2d(1, 16, kernel_size=3, stride=2, padding=1),  # (batch_size, 1, dim_1, dim_2) -> (batch_size, 16, 20, 8)
            torch.nn.BatchNorm2d(num_features=16),
            torch.nn.ReLU(),
            torch.nn.Conv2d(16, 32, kernel_size=3, stride=2, padding=1),  # (batch_size, 16, 20, 8) -> (batch_size, 32, 10, 4)
            torch.nn.BatchNorm2d(num_features=32),
            torch.nn.ReLU(),
            torch.nn.Flatten(),  # (batch_size, 32, 10, 4) -> (batch_size, 1280)
            torch.nn.Linear(32*10*4, dim_1_reduced * dim_2_reduced),  # (batch_size, 1280) -> (batch_size, dim_1_reduced * dim_2_reduced)
            torch.nn.ReLU(),
            torch.nn.Unflatten(1, (dim_1_reduced , dim_2_reduced))  # Reshape to (batch_size, dim_1_reduced, dim_2_reduced)
        )

        # Decoder
        self.decoder = torch.nn.Sequential(
      torch.nn.Flatten(1),
      torch.nn.Linear(18 * 8, 32 * 10 * 4),  # (batch_size, dim_1_reduced * dim_2_reduced) -> (batch_size, 32*10*4)
      torch.nn.BatchNorm1d(32 * 10 * 4),  # Batch normalization before ReLU
      torch.nn.ReLU(),
      torch.nn.Unflatten(1, (32, 10, 4)),  # (batch_size, 32*10*4) -> (batch_size, 32, 10, 4)
      torch.nn.ConvTranspose2d(32, 16, kernel_size=3, stride=2, padding=1, output_padding=(1, 1)),  # (batch_size, 32, 10, 4) -> (batch_size, 16, 20, 8)
      torch.nn.BatchNorm2d(16),  # Batch normalization before ReLU
      torch.nn.ReLU(),
      torch.nn.ConvTranspose2d(16, 1, kernel_size=3, stride=2, padding=1, output_padding=(0, 1)),  # (batch_size, 16, 20, 8) -> (batch_size, 1, 39, 16)

)


    def forward(self, par, out):
        Z1 = self.mlp(par)  # (dim_1_reduced * dim_2_reduced)

        out_squeezed = out.unsqueeze(1)
          # Adding channel dimension to input
        Z2 = self.encoder(out_squeezed)  # (dim_1_reduced * dim_2_reduced)

        Z3 = self.decoder(Z2) # (batch_siz, 1, dim_1, dim_2)
        Z3=Z3.squeeze(1)  # (batch_siz, dim_1, dim_2)

        return Z1, Z2, Z3

    def predict(self, par):
        Z = self.mlp(par)  # (dim_1_reduced * dim_2_reduced)
        Z = self.decoder(Z)  # (batch_size, 1, dim_1, dim_2)
        Z=Z.squeeze(1)
        return Z

# %%
model = MLP_press_ConvAutoencoder()
  # Valori casuali tra 0 e 1
z1, z2, z3= model.forward(train_params,train_vel)

# %%
z1.shape
# Out:
# torch.Size([1560, 18, 8])

# %%
z2.shape
# Out:
# torch.Size([1560, 18, 8])

# %%
z3.shape
# Out:
# torch.Size([1560, 39, 16])

# %%
#I'M USING THIS AT THE MOMENT

class MLP_press_ConvAutoencoder_2(torch.nn.Module):
    def __init__(self, parameters=3, dim_1=39, dim_2=16, dim_reduced=128, L=4, K=256):
        super(MLP_press_ConvAutoencoder_2, self).__init__()

        self.mlp = torch.nn.Sequential(
            *[layer for i in range(L) for layer in [
                torch.nn.Linear(parameters if i == 0 else K, K),
                torch.nn.LayerNorm(K),
                torch.nn.ReLU(),
            ]],
            torch.nn.Linear(K, dim_reduced), #(batch_size, K) -> (batch_size, dim_reduced)

        )

        # Encoder

        self.encoder = torch.nn.Sequential(
            torch.nn.Conv2d(1, 64, kernel_size=5, stride=2, padding=1),  # (batch_size, 1, dim_1, dim_2) -> (batch_size, 64, 19, 7)
            #torch.nn.BatchNorm2d(64),
            torch.nn.ReLU(),
            torch.nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1), # (batch_size, 64, 19, 7) -> (batch_size, 128, 10, 4)
            #torch.nn.BatchNorm2d(128),
            torch.nn.ReLU(),
            torch.nn.Flatten(),      #(batch_size, 128, 10, 4) -> (batch_size, 128 x 10 x 4)
            torch.nn.Linear(128*10*4, 256),    #(batch_size, 128 x 10 x 4) ->  batch_size, 256)
            #torch.nn.Dropout(p=0.3)
            torch.nn.ReLU(),
            torch.nn.Linear(256, dim_reduced)  #(batch_size, 256) ->  (batch_size, dim_reduced)

        )


        # Decoder
        self.decoder = torch.nn.Sequential(
            torch.nn.Linear(dim_reduced, 256),    # (batch_size, dim_reduced)-> #(batch_size, 256)
            torch.nn.ReLU(),
            torch.nn.Linear(256, 128*10*4), # (batch_size, 256)-> #(batch_size, 128*10*4)
            torch.nn.ReLU(),
            torch.nn.Unflatten(1, (128, 10, 4)),      #(batch_size, 128*10*4) -> (batch_size, 128, 10, 4)
            torch.nn.ConvTranspose2d(128, 64, kernel_size=3, stride=2, padding=1, output_padding=(0, 0)), # (batch_size, 128, 10, 4) -> # (batch_size, 64, 19, 7)
            #torch.nn.BatchNorm2d(64),
            torch.nn.ReLU(),
            torch.nn.ConvTranspose2d(64, 1, kernel_size=5, stride=2, padding=1, output_padding=(0, 1)),   # -> (batch_size, 64, 19, 7) --> (batch_size, 1, dim_1, dim_2)
            #torch.nn.Sigmoid()
        )


    def forward(self, par, out):
        Z1 = self.mlp(par)  # (batch_size, dim_reduced)

        out_squeezed = out.unsqueeze(1) #(batch_size x 39 x 16) -> #(batch_size x 1 x 39 x 16)
        Z2 = self.encoder(out_squeezed)  # (batch_size, dim_reduced)

        Z3 = self.decoder(Z2) # (batch_siz, 1, dim_1, dim_2)
        Z3=Z3.squeeze(1)  # (batch_siz, dim_1, dim_2)

        return Z1, Z2, Z3

    def predict(self, par):
        Z = self.mlp(par)  # (dim_1_reduced * dim_2_reduced)
        Z = self.decoder(Z)  # (batch_size, 1, dim_1, dim_2)
        Z=Z.squeeze(1)
        return Z

# %%
model = MLP_press_ConvAutoencoder_2()
  # Valori casuali tra 0 e 1
z1, z2, z3= model.forward(train_params,train_vel)

# %%
z1.shape
# Out:
# torch.Size([1560, 128])

# %%
z2.shape
# Out:
# torch.Size([1560, 128])

# %%
z3.shape
# Out:
# torch.Size([1560, 39, 16])

# %%
#TODO: normalize input of encoder

def train_encoder_decoder_epoch(model, device, train_loader, optimizer, epoch, criterion):
    model.train()  # Important set model to train mode (affects dropout, batch norm etc)

    loss_history = []
    accuracy_history = []
    loss_history_enc_dec = []
    loss_history_mlp_encoder = []
    for batch_idx, (data, target) in enumerate(train_loader):


        data=data.to(device)
        target=target.to(device)

        Z1, Z2, Z3 = model.forward(data, target)

        assert Z3.shape == target.shape
        assert Z1.shape == Z2.shape

        Z3_flattened = Z3.flatten(1)
        target_fattened = target.flatten(1)

        loss_enc_dec =  criterion(target_fattened, Z3_flattened)
        loss_mlp_encoder = criterion(Z1, Z2)


        loss =  loss_enc_dec + loss_mlp_encoder

        optimizer.zero_grad()  # Zero the gradients

        loss.backward()        # Backpropagation
        optimizer.step()       # Update the weights

        loss_history_enc_dec.append(loss_enc_dec.item())
        loss_history_mlp_encoder.append(loss_mlp_encoder.item())
        loss_history.append(loss.item())

    return loss_history, loss_history_enc_dec, loss_history_mlp_encoder

@torch.no_grad()
def validate(model, device, val_loader, criterion):
    model.eval()  # Important set model to eval mode (affects dropout, batch norm etc)
    test_loss = 0
    test_rel_loss = 0
    for data, target in val_loader:

        data, target = data.to(device), target.to(device)
        output = model.predict(data)
        assert output.shape == target.shape

        output_flattened = output.flatten(1)
        target_flattened = target.flatten(1)
        test_loss += criterion(output_flattened, target_flattened).item() * len(data)

        test_rel_loss += ((torch.norm((output-target).view(output.shape[0], -1), dim=1, p=2)/torch.norm((target).view(output.shape[0], -1), dim=1, p=2)).sum()).item()
    test_loss /= len(val_loader.dataset)
    test_rel_loss /= len(val_loader.dataset)

    print(
         "Test set: Average loss: {:.4f} Average relative error: {:.4f}".format(
           test_loss, test_rel_loss
        )
    )
    return test_loss,test_rel_loss


def run_vel_training_encoder_decoder(num_epochs, lr, batch_size, device="cuda"):

    train_vel_DataSet = Fluid_Dataset(train_params, train_vel)
    test_vel_DataSet = Fluid_Dataset(test_params, test_vel)

    train_loader = torch.utils.data.DataLoader(
        train_vel_DataSet,
        batch_size=batch_size,
        shuffle=True,  # Can be important for training
        pin_memory=torch.cuda.is_available(),
        drop_last=True,
        num_workers=2,
    )
    val_loader = torch.utils.data.DataLoader(
        test_vel_DataSet,
        batch_size=batch_size,
    )

    # ===== Model, Optimizer and Criterion =====
    model_encoder_decoder= MLP_press_ConvAutoencoder_2()
    model_encoder_decoder = model_encoder_decoder.to(device=device)
    optimizer_encoder_decoder  = torch.optim.Adam(
        model_encoder_decoder.parameters(),
        lr=lr,
        weight_decay=1e-3
    )
    criterion_mlp = torch.nn.functional.mse_loss

    # ===== Train Model =====
    train_loss_history = []
    train_loss_enc_dec_history = []
    train_loss_mlp_enc_history = []
    val_loss_history = []
    val_rel_loss_history = []

    for epoch in range(1, num_epochs + 1):
        train_loss, trai_loss_enc_dec, train_loss_mlp_enc = train_encoder_decoder_epoch(
            model_encoder_decoder, device, train_loader, optimizer_encoder_decoder, epoch, criterion_mlp
        )
        train_loss_history.extend(train_loss)
        train_loss_enc_dec_history.extend(trai_loss_enc_dec)
        train_loss_mlp_enc_history.extend(train_loss_mlp_enc)

        val_loss,val_rel_loss= validate(model_encoder_decoder, device, val_loader, criterion_mlp)
        val_loss_history.append(val_loss)
        val_rel_loss_history.append(val_rel_loss)


    # ===== Plot training curves =====
    n_train = len(train_loss_history)
    t_train = num_epochs * np.arange(n_train) / n_train
    t_val = np.arange(1, num_epochs + 1)

    plt.figure()
    plt.plot(t_train, train_loss_history, label="Train")
    plt.plot(t_val, val_loss_history, label="Val")
    plt.legend()
    plt.xlabel("Epoch")
    plt.ylabel("Loss")

    plt.figure()
    plt.plot(t_train, train_loss_enc_dec_history, label="Train enc dec")
    plt.plot(t_train, train_loss_mlp_enc_history, label="Train mlp enc")
    plt.legend()
    plt.xlabel("Epoch")
    plt.ylabel("Loss")

    plt.figure()
    plt.plot(t_val, val_rel_loss_history, label="Val rel err")
    plt.legend()
    plt.xlabel("Epoch")
    plt.ylabel("rel err")

    return model_encoder_decoder, val_loss_history[-1], val_rel_loss_history[-1]

# %%
batch_size=32
num_epochs=200
lr=0.0001
#device=torch.device('cpu')
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model_trained,  val_loss, val_rel_loss = run_vel_training_encoder_decoder(num_epochs, lr, batch_size, device)
# Out:
# Test set: Average loss: 50.9715 Average relative error: 0.9781
# Test set: Average loss: 34.9979 Average relative error: 0.8099
# Test set: Average loss: 14.2097 Average relative error: 0.5133
# Test set: Average loss: 4.7357 Average relative error: 0.2827
# Test set: Average loss: 4.6032 Average relative error: 0.2778
# Test set: Average loss: 4.6113 Average relative error: 0.2778
# Test set: Average loss: 4.6160 Average relative error: 0.2779
# Test set: Average loss: 4.6083 Average relative error: 0.2776
# Test set: Average loss: 4.6076 Average relative error: 0.2774
# Test set: Average loss: 4.2915 Average relative error: 0.2686
# Test set: Average loss: 3.2809 Average relative error: 0.2355
# Test set: Average loss: 2.1312 Average relative error: 0.1919
# Test set: Average loss: 1.7892 Average relative error: 0.1765
# Test set: Average loss: 1.7076 Average relative error: 0.1727
# Test set: Average loss: 1.6855 Average relative error: 0.1716
# Test set: Average loss: 1.6722 Average relative error: 0.1708
# Test set: Average loss: 1.6716 Average relative error: 0.1708
# Test set: Average loss: 1.6692 Average relative error: 0.1707
# Test set: Average loss: 1.6674 Average relative error: 0.1706
# Test set: Average loss: 1.6645 Average relative error: 0.1705
# Test set: Average loss: 1.6581 Average relative error: 0.1700
# Test set: Average loss: 1.6582 Average relative error: 0.1701
# Test set: Average loss: 1.6569 Average relative error: 0.1700
# Test set: Average loss: 1.6588 Average relative error: 0.1701
# Test set: Average loss: 1.6598 Average relative error: 0.1703
# Test set: Average loss: 1.6611 Average relative error: 0.1703
# Test set: Average loss: 1.6644 Average relative error: 0.1703
# Test set: Average loss: 1.6568 Average relative error: 0.1700
# Test set: Average loss: 1.6558 Average relative error: 0.1698
# Test set: Average loss: 1.6551 Average relative error: 0.1698
# Test set: Average loss: 1.6566 Average relative error: 0.1700
# Test set: Average loss: 1.6543 Average relative error: 0.1697
# Test set: Average loss: 1.6654 Average relative error: 0.1706
# Test set: Average loss: 1.6530 Average relative error: 0.1697
# Test set: Average loss: 1.6529 Average relative error: 0.1698
# Test set: Average loss: 1.6493 Average relative error: 0.1696
# Test set: Average loss: 1.6305 Average relative error: 0.1685
# Test set: Average loss: 1.5587 Average relative error: 0.1647
# Test set: Average loss: 1.4693 Average relative error: 0.1599
# Test set: Average loss: 1.4371 Average relative error: 0.1580
# Test set: Average loss: 1.4205 Average relative error: 0.1570
# Test set: Average loss: 1.3942 Average relative error: 0.1554
# Test set: Average loss: 1.3667 Average relative error: 0.1537
# Test set: Average loss: 1.3283 Average relative error: 0.1512
# Test set: Average loss: 1.2890 Average relative error: 0.1486
# Test set: Average loss: 1.2576 Average relative error: 0.1467
# Test set: Average loss: 1.2321 Average relative error: 0.1448
# Test set: Average loss: 1.2095 Average relative error: 0.1433
# Test set: Average loss: 1.1916 Average relative error: 0.1422
# Test set: Average loss: 1.1711 Average relative error: 0.1410
# Test set: Average loss: 1.1508 Average relative error: 0.1396
# Test set: Average loss: 1.1398 Average relative error: 0.1391
# Test set: Average loss: 1.1189 Average relative error: 0.1377
# Test set: Average loss: 1.0947 Average relative error: 0.1359
# Test set: Average loss: 1.0799 Average relative error: 0.1348
# Test set: Average loss: 1.0686 Average relative error: 0.1341
# Test set: Average loss: 1.0232 Average relative error: 0.1310
# Test set: Average loss: 0.9724 Average relative error: 0.1277
# Test set: Average loss: 0.9200 Average relative error: 0.1243
# Test set: Average loss: 0.8445 Average relative error: 0.1186
# Test set: Average loss: 0.7873 Average relative error: 0.1142
# Test set: Average loss: 0.7431 Average relative error: 0.1107
# Test set: Average loss: 0.7049 Average relative error: 0.1081
# Test set: Average loss: 0.6610 Average relative error: 0.1045
# Test set: Average loss: 0.6157 Average relative error: 0.1011
# Test set: Average loss: 0.5834 Average relative error: 0.0983
# Test set: Average loss: 0.5368 Average relative error: 0.0941
# Test set: Average loss: 0.5027 Average relative error: 0.0911
# Test set: Average loss: 0.4867 Average relative error: 0.0897
# Test set: Average loss: 0.4463 Average relative error: 0.0857
# Test set: Average loss: 0.4139 Average relative error: 0.0824
# Test set: Average loss: 0.3872 Average relative error: 0.0796
# Test set: Average loss: 0.3686 Average relative error: 0.0778
# Test set: Average loss: 0.3410 Average relative error: 0.0747
# Test set: Average loss: 0.3256 Average relative error: 0.0731
# Test set: Average loss: 0.3106 Average relative error: 0.0712
# Test set: Average loss: 0.2967 Average relative error: 0.0698
# Test set: Average loss: 0.2800 Average relative error: 0.0675
# Test set: Average loss: 0.2567 Average relative error: 0.0651
# Test set: Average loss: 0.2471 Average relative error: 0.0637
# Test set: Average loss: 0.2308 Average relative error: 0.0616
# Test set: Average loss: 0.2193 Average relative error: 0.0604
# Test set: Average loss: 0.2057 Average relative error: 0.0583
# Test set: Average loss: 0.1944 Average relative error: 0.0567
# Test set: Average loss: 0.1866 Average relative error: 0.0556
# Test set: Average loss: 0.1809 Average relative error: 0.0547
# Test set: Average loss: 0.1749 Average relative error: 0.0537
# Test set: Average loss: 0.1679 Average relative error: 0.0530
# Test set: Average loss: 0.1613 Average relative error: 0.0517
# Test set: Average loss: 0.1537 Average relative error: 0.0508
# Test set: Average loss: 0.1486 Average relative error: 0.0497
# Test set: Average loss: 0.1464 Average relative error: 0.0493
# Test set: Average loss: 0.1390 Average relative error: 0.0483
# Test set: Average loss: 0.1429 Average relative error: 0.0492
# Test set: Average loss: 0.1350 Average relative error: 0.0475
# Test set: Average loss: 0.1343 Average relative error: 0.0476
# Test set: Average loss: 0.1303 Average relative error: 0.0469
# Test set: Average loss: 0.1272 Average relative error: 0.0462
# Test set: Average loss: 0.1241 Average relative error: 0.0457
# Test set: Average loss: 0.1214 Average relative error: 0.0451
# Test set: Average loss: 0.1194 Average relative error: 0.0447
# Test set: Average loss: 0.1172 Average relative error: 0.0444
# Test set: Average loss: 0.1127 Average relative error: 0.0433
# Test set: Average loss: 0.1176 Average relative error: 0.0447
# Test set: Average loss: 0.1091 Average relative error: 0.0426
# Test set: Average loss: 0.1101 Average relative error: 0.0430
# Test set: Average loss: 0.1093 Average relative error: 0.0428
# Test set: Average loss: 0.1054 Average relative error: 0.0420
# Test set: Average loss: 0.1047 Average relative error: 0.0419
# Test set: Average loss: 0.1056 Average relative error: 0.0422
# Test set: Average loss: 0.1046 Average relative error: 0.0418
# Test set: Average loss: 0.1000 Average relative error: 0.0408
# Test set: Average loss: 0.1016 Average relative error: 0.0413
# Test set: Average loss: 0.0978 Average relative error: 0.0404
# Test set: Average loss: 0.0963 Average relative error: 0.0402
# Test set: Average loss: 0.0992 Average relative error: 0.0408
# Test set: Average loss: 0.0929 Average relative error: 0.0396
# Test set: Average loss: 0.0918 Average relative error: 0.0392
# Test set: Average loss: 0.0921 Average relative error: 0.0393
# Test set: Average loss: 0.0924 Average relative error: 0.0394
# Test set: Average loss: 0.0919 Average relative error: 0.0393
# Test set: Average loss: 0.0898 Average relative error: 0.0388
# Test set: Average loss: 0.0871 Average relative error: 0.0382
# Test set: Average loss: 0.0849 Average relative error: 0.0377
# Test set: Average loss: 0.0856 Average relative error: 0.0380
# Test set: Average loss: 0.0843 Average relative error: 0.0376
# Test set: Average loss: 0.0830 Average relative error: 0.0373
# Test set: Average loss: 0.0821 Average relative error: 0.0370
# Test set: Average loss: 0.0817 Average relative error: 0.0370
# Test set: Average loss: 0.0825 Average relative error: 0.0371
# Test set: Average loss: 0.0803 Average relative error: 0.0366
# Test set: Average loss: 0.0807 Average relative error: 0.0368
# Test set: Average loss: 0.0807 Average relative error: 0.0368
# Test set: Average loss: 0.0787 Average relative error: 0.0363
# Test set: Average loss: 0.0792 Average relative error: 0.0365
# Test set: Average loss: 0.0775 Average relative error: 0.0360
# Test set: Average loss: 0.0767 Average relative error: 0.0359
# Test set: Average loss: 0.0782 Average relative error: 0.0361
# Test set: Average loss: 0.0760 Average relative error: 0.0357
# Test set: Average loss: 0.0741 Average relative error: 0.0351
# Test set: Average loss: 0.0742 Average relative error: 0.0352
# Test set: Average loss: 0.0747 Average relative error: 0.0353
# Test set: Average loss: 0.0764 Average relative error: 0.0358
# Test set: Average loss: 0.0740 Average relative error: 0.0352
# Test set: Average loss: 0.0753 Average relative error: 0.0355
# Test set: Average loss: 0.0744 Average relative error: 0.0353
# Test set: Average loss: 0.0758 Average relative error: 0.0357
# Test set: Average loss: 0.0727 Average relative error: 0.0348
# Test set: Average loss: 0.0721 Average relative error: 0.0348
# Test set: Average loss: 0.0749 Average relative error: 0.0356
# Test set: Average loss: 0.0780 Average relative error: 0.0362
# Test set: Average loss: 0.0724 Average relative error: 0.0349
# Test set: Average loss: 0.0714 Average relative error: 0.0345
# Test set: Average loss: 0.0748 Average relative error: 0.0354
# Test set: Average loss: 0.0705 Average relative error: 0.0344
# Test set: Average loss: 0.0687 Average relative error: 0.0339
# Test set: Average loss: 0.0694 Average relative error: 0.0341
# Test set: Average loss: 0.0698 Average relative error: 0.0341
# Test set: Average loss: 0.0704 Average relative error: 0.0343
# Test set: Average loss: 0.0695 Average relative error: 0.0341
# Test set: Average loss: 0.0680 Average relative error: 0.0337
# Test set: Average loss: 0.0698 Average relative error: 0.0341
# Test set: Average loss: 0.0682 Average relative error: 0.0338
# Test set: Average loss: 0.0674 Average relative error: 0.0336
# Test set: Average loss: 0.0684 Average relative error: 0.0339
# Test set: Average loss: 0.0664 Average relative error: 0.0333
# Test set: Average loss: 0.0668 Average relative error: 0.0334
# Test set: Average loss: 0.0682 Average relative error: 0.0337
# Test set: Average loss: 0.0680 Average relative error: 0.0338
# Test set: Average loss: 0.0723 Average relative error: 0.0347
# Test set: Average loss: 0.0676 Average relative error: 0.0337
# Test set: Average loss: 0.0679 Average relative error: 0.0336
# Test set: Average loss: 0.0665 Average relative error: 0.0334
# Test set: Average loss: 0.0665 Average relative error: 0.0333
# Test set: Average loss: 0.0641 Average relative error: 0.0327
# Test set: Average loss: 0.0649 Average relative error: 0.0329
# Test set: Average loss: 0.0673 Average relative error: 0.0336
# Test set: Average loss: 0.0648 Average relative error: 0.0329
# Test set: Average loss: 0.0648 Average relative error: 0.0328
# Test set: Average loss: 0.0647 Average relative error: 0.0328
# Test set: Average loss: 0.0636 Average relative error: 0.0326
# Test set: Average loss: 0.0676 Average relative error: 0.0337
# Test set: Average loss: 0.0644 Average relative error: 0.0328
# Test set: Average loss: 0.0672 Average relative error: 0.0336
# Test set: Average loss: 0.0641 Average relative error: 0.0327
# Test set: Average loss: 0.0684 Average relative error: 0.0339
# Test set: Average loss: 0.0642 Average relative error: 0.0327
# Test set: Average loss: 0.0632 Average relative error: 0.0324
# Test set: Average loss: 0.0666 Average relative error: 0.0333
# Test set: Average loss: 0.0657 Average relative error: 0.0332
# Test set: Average loss: 0.0619 Average relative error: 0.0321
# Test set: Average loss: 0.0649 Average relative error: 0.0330
# Test set: Average loss: 0.0657 Average relative error: 0.0331
# Test set: Average loss: 0.0642 Average relative error: 0.0328
# Test set: Average loss: 0.0632 Average relative error: 0.0323
# Test set: Average loss: 0.0625 Average relative error: 0.0322
# Test set: Average loss: 0.0654 Average relative error: 0.0331
# Test set: Average loss: 0.0621 Average relative error: 0.0321
# Test set: Average loss: 0.0627 Average relative error: 0.0322
# Test set: Average loss: 0.0623 Average relative error: 0.0322

# %%
#find best num_epoch and learning rate

batch_size=32
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
val_losses=[]
val_rel_losses=[]
for lr in list(np.linspace(0.0001, 0.001, 50)):
  for num_epochs in list(np.linspace(50 , 200, 20).astype(int)):

        model_trained,  val_loss, val_rel_loss = run_vel_training_encoder_decoder(num_epochs, lr, batch_size, device)
        val_losses.append(val_loss)
        val_rel_losses.append(val_rel_loss)

# %%
print(device)

# %%
model = Simple_Model()
  # Valori casuali tra 0 e 1
z1, z2, z3= model.forward(train_params,train_vel)

# %%
z1.shape
# Out:
# torch.Size([1560, 18, 8])

# %%
z2.shape
# Out:
# torch.Size([1560, 18, 8])

# %%
z3.shape
# Out:
# torch.Size([1560, 5, 5])

# %%
z=model.predict(train_params)

# %%
z.shape
# Out:
# torch.Size([1560, 5, 5])

# %%
c = torch.randn((5,3,2))
c.shape
# Out:
# torch.Size([5, 3, 2])

# %%
c_shaped=c.view(c.shape[0], -1)

# %%
c_shaped.shape
# Out:
# torch.Size([5, 6])

# %%
c_shaped
# Out:
# tensor([[ 0.0247,  0.5999,  1.3813, -0.8010,  1.7893, -1.3100],
#         [-0.0918,  1.5952, -0.1132, -1.1700,  0.2491,  2.2126],
#         [-0.3063,  1.1698,  0.2230,  0.6958,  0.5637, -1.1418],
#         [ 0.4004,  0.7669,  0.3747,  1.3313,  0.7806,  0.3532],
#         [-0.2890,  0.9966,  1.9221,  0.0194, -1.7310,  1.0572]])

# %%
torch.norm(c_shaped, dim=1)
# Out:
# tensor([2.7979, 2.9821, 1.9020, 1.8426, 2.9809])

# %%
def read_vtk(filename):
    """Read .vtk file and return the polydata"""

    fn_dir, fn_ext = os.path.splitext(filename)

    if fn_ext == '.vtk':
        reader = vtk.vtkPolyDataReader()
    elif fn_ext == '.vtp':
        reader = vtk.vtkXMLPolyDataReader()
    elif fn_ext == '.stl':
        reader = vtk.vtkSTLReader()
    elif fn_ext == '.obj':
        reader = vtk.vtkOBJReader()
    elif fn_ext == '.vtu':
        reader = vtk.vtkXMLUnstructuredGridReader()
    elif fn_ext == '.pvtu':
        reader = vtk.vtkXMLPUnstructuredGridReader()
    else:
        raise ValueError(F"File extension {fn_ext} not supported")

    reader.SetFileName(filename)
    reader.Update(0)
    mesh = reader.GetOutput()

    return mesh

def write_vtk(mesh, fn):
    """ Write a mesh (vtk polydata or unstructured grid) to disk """

    _, extension = os.path.splitext(fn)

    if extension == '.vtk':
        writer = vtk.vtkPolyDataWriter()
    elif extension == '.stl':
        writer = vtk.vtkSTLWriter()
    elif extension == '.vtp':
        writer = vtk.vtkXMLPolyDataWriter()
    elif extension == '.vtu':
        writer = vtk.vtkXMLUnstructuredGridWriter()
    elif extension == '.obj':
        writer = vtk.vtkOBJWriter()
    else:
        raise ValueError(f"Unrecognized extension {extension}")

    writer.SetInputData(mesh)
    writer.SetFileName(fn)
    writer.Update(0)
    writer.Write()

    return

def add_array(mesh, array, name):
    """Add numpy array as new field to a vtk file"""

    new_array = numpy_to_vtk(array)
    new_array.SetName(name)
    mesh.GetPointData().AddArray(new_array)

    return mesh

def compute_matching_idxs():
    """Compute correspondences bewteen indices on the .vtu and on the .mesh file for plotting"""

    mesh = read_vtk(os.path.join('/content/drive/MyDrive/data_ML4Science', 'geometries', 'bif_sym_alpha50_h0.10_ref.vtu'))
    points = vtk_to_numpy(mesh.GetPoints().GetData())

    mesh_2 = meshio.read(os.path.join('/content/drive/MyDrive/data_ML4Science', 'geometries','bif_sym_alpha50_h0.10.mesh'))
    points_2 = mesh_2.points

    dist = cdist(mesh_2.points, points, metric='euclidean')

    idxs = np.argmin(dist, axis=0)

    return idxs


def visualize_solution(field_array, fields=None, step_t=10):
    """ Export the solution corresponding to the n-th snapshot (every step_t steps) to a .vtu file."""

    if fields is None:
        fields = {'velocity': 3, 'pressure': 1}  # fields and corresponding dimensions

    os.makedirs('solutions', exist_ok=True)

    idxs = compute_matching_idxs()

    mesh = read_vtk(os.path.join('/content/drive/MyDrive/data_ML4Science', 'geometries', 'bif_sym_alpha50_h0.10.vtu'))

    fom_solution = dict()
    for field in fields:
        # print(f"Processing field {field} - Dimension: {fields[field]}")
        cur_idxs = np.hstack([idxs + k * (Nh_space[field]//fields[field]) for k in range(fields[field])])
        fom_solution[field] = expand(field_array, basis_space[field], basis_time[field])[cur_idxs]
        print(fom_solution[field].shape)

    for cnt_t in range(0, Nh_time['velocity'], step_t):
        # print(f"\nProcessing timestep {cnt_t} of {Nh_time['velocity']}")
        for field in fields:
            cur_fom_solution = np.reshape(fom_solution[field][:, cnt_t], (fields[field], -1)).T
            mesh = add_array(mesh, cur_fom_solution, field)

        # write_vtk(mesh, os.path.join('solutions', f"solution_{n}_{cnt_t}" + '.vtu'))
        write_vtk(mesh, os.path.join('solutions', f"solution_{cnt_t}" + '.vtu'))

    return

# %%
model_trained.eval()

input_tensor = torch.tensor(test_params[0,:], dtype=torch.float32)  # Trasforma in tensore
input_tensor = input_tensor.unsqueeze(dim=0)
input_tensor = input_tensor.to(device)  # Se usi la GPU

with torch.no_grad():
    output_visual = model_trained(input_tensor)
    output_visual=output_visual[0]
    print(output_visual.shape)

visualize_solution(output_visual.cpu().numpy() ,fields={'velocity': 3},step_t=5)

# %%
# !zip -r solutions.zip solutions
from google.colab import files
files.download('solutions.zip')
